# %%
1. arithmatic operator question

# %%
a = 15 
b = 20
total = a+ b
print (total)
# Out:
# 35

# %%
a = 50 
b = 18
total = a - b
print (total)
# Out:
# 32

# %%
a = 9 
b = 7
total = a * b
print (total)
# Out:
# 63

# %%
a = 5000 
b = 2
total = a % b
print (total)
# Out:
# 0

# %%
a = 12
a **= 2
print(a)
# Out:
# 144

# %%
a = 5
a **= 3
print(a)
# Out:
# 125

# %%
a = 29
b = 5
total = a // b
print (total)
# Out:
# 5

# %%
2. camparison operator question

# %%
a = 10
b = 5
c = a>b
print(c)
# Out:
# True

# %%
a = 15
b = 25
c = a<b
print(c)
# Out:
# True

# %%
a = 20
b = 20
c = a == b
print(c)
# Out:
# True

# %%
a = 30
b = 10
c = a != b
print(c)
# Out:
# True

# %%
a = 45
b = 40
c = a >= b
print(c)
# Out:
# True

# %%
a = 8
b = 3
c = a <= b
print(c)
# Out:
# False

# %%
3. logical operator question

# %%
a = "this is my python class"
b = "3"

a1 = "this is my python class"
b1 = "4"
print(a == a1 and b ==b1)
# Out:
# False

# %%
a = "this is my python class"
b = "3"

a1 = "this is my python class"
b1 = "4"
print(a == a1 or b ==b1)
# Out:
# True

# %%
a = "this is my python class"
b = "3"
print (not(a ==b))
# Out:
# True

# %%
a = "this is my python class"
b = "this is my python class"
print (not(a ==b))
# Out:
# False

# %%
4. assignment operator question

# %%
x = 10
x += 5
print(x)
# Out:
# 15

# %%
x = 20
x -= 4
print(x)
# Out:
# 16

# %%
x = 6
x *= 3
print(x)
# Out:
# 18

# %%
x = 40
x /= 2
print(x)
# Out:
# 20.0

# %%
x = 5
x **= 2
print(x)
# Out:
# 25

# %%
x = 20
x %= 3
print(x)
# Out:
# 2

# %%
5. identity operator question

# %%
a = 10
b = 10
print(a is b)
# Out:
# True

# %%
a = 10
b = 10
print(a is b)

# %%
a = [1 , 2 , 3]
b = [1 , 2 , 3]
print(a is b)
# Out:
# False

# %%
a = 9
b = 7
print(a is not b)
print(id(a))
print(id(b))
# Out:
# True
# 140728062682280
# 140728062682216

# %%
6. membership operator question

# %%
x = "apple"
print(a in x)
# Out:
# True

# %%
a = "python"
print("x" not in a)
# Out:
# True

# %%
a = [1 ,2 ,3 ,4 ,5]
print(3 in a)
# Out:
# True
